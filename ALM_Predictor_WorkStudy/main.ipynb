# %% [markdown]
# ### Prediction of Skeletal Muscle Mass with DXA Scan Accuracy Using Smartphone Imaging
#
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

pd.set_option('display.max_columns', 55)

# %% [markdown]
# # Datasets
#
# * DXA - represents the data from the DXA scans
#
# * SS20 - represents the data captured from smartphone 3D imaging (Size Stream Scan)

# %%
dfs = {
    'dxa': {
        'file' : './data/MusclePredictionAnalysis(002).xlsx',
        'sheet' : 'All DXA',
        #'cols' : range(7, 32) 
    },
    'ss20': {
        'file': './data/MusclePredictionAnalysis(002).xlsx',
        'sheet': 'All SS20',
        #'cols': range(6, 52)
    }
}

input_df = dfs['ss20']
output_df = dfs['dxa']

# in_data  = pd.read_excel(input_df['file'], sheet_name=input_df['sheet'], usecols=input_df['cols'])
# out_data = pd.read_excel(output_df['file'], sheet_name=output_df['sheet'], usecols=output_df['cols'])
in_data  = pd.read_excel(input_df['file'], sheet_name=input_df['sheet'])
out_data = pd.read_excel(output_df['file'], sheet_name=output_df['sheet'],)

# %% [markdown]
# # Filling Missing Values

# %%
in_data.isna().any(), out_data.isna().any()
# Out:
# (0                                False
#  PPT ID                            True
#  Site                             False
#  Age                              False
#  Gender                           False
#  Race                             False
#  ALM                              False
#  ALM (adjusted)                   False
#  Height (cm)                      False
#  Weight (kg)                      False
#  Abdomen Circumference             True
#  Ankle Circumference Left          True
#  Arm Length Left                   True
#  Arm Volume Left                   True
#  Bicep Circumference Left          True
#  Calf Circumference Left           True
#  Chest                             True
#  Collar Circumference              True
#  Forearm Circumference Left        True
#  Head Circumference                True
#  Hip Circumference                 True
#  Horizontal Waist                  True
#  Inseam Left                       True
#  Leg Volume Left                   True
#  MidThigh Circumference Left       True
#  Narrow Waist                      True
#  Outside Leg Length Left           True
#  Seat Circumference                True
#  Surface Area Arm Left             True
#  Surface Area Leg Left             True
#  Surface Area Torso                True
#  Surface Area Total                True
#  Thigh Circumference Left          True
#  Torso Volume                      True
#  Upper Arm Circumference Left      True
#  Volume                            True
#  Waist Circumference               True
#  Subject Height                    True
#  Ankle Circumference Right         True
#  Arm Length Right                  True
#  Arm Volume Right                  True
#  Bicep Circumference Right         True
#  Calf Circumference Right          True
#  Forearm Circumference Right       True
#  Inseam Right                      True
#  Leg Volume Right                  True
#  MidThigh Circumference Right      True
#  Outside Leg Length Right          True
#  1  Surface Area Arm Right         True
#  1  Surface Area Leg Right         True
#  1  Thigh Circumference Right      True
#  Upper Arm Circumference Right     True
#  dtype: bool,
#  0                        False
#  Subject ID               False
#  Age                      False
#  Height (cm)               True
#  Weight                    True
#  Gender                   False
#  Race                     False
#  DXA Weight               False
#  Total Fat                 True
#  Total Lean               False
#  Total BMC                 True
#  ALM                      False
#  ALM (adjusted)           False
#  Fat Mass - Total          True
#  Lean Mass - Total         True
#  Bone Mass - Total         True
#  ALM.1                    False
#  Fat Mass - Trunk          True
#  Lean Mass - Trunk         True
#  Bone Mass - Trunk         True
#  Fat Mass - Left Arm       True
#  Lean Mass - Left Arm     False
#  Bone Mass - Left Arm      True
#  Fat Mass - Left Leg       True
#  Lean Mass - Left Leg     False
#  Bone Mass - Left Leg      True
#  Fat Mass - Right Arm      True
#  Lean Mass - Right Arm    False
#  Bone Mass - Right Arm     True
#  Fat Mass - Right Leg      True
#  Lean Mass - Right Leg    False
#  Bone Mass - Right Leg     True
#  dtype: bool)

# %%
len(in_data.columns), len(out_data.columns)
# Out:
# (52, 32)

# %%
in_data = in_data.drop(columns = [0, 'PPT ID', 'Site'])

# %%
in_data
# Out:
#      Age  Gender                       Race        ALM  ALM (adjusted)  \
# 0     41  Female  Black or African American  30.284662       30.284662
# 1     33  Female                      Asian  21.228207       21.228207
# 2     65    Male  Black or African American  25.601226       25.601226
# 3     45  Female  Black or African American  20.277196       20.277196
# 4     22  Female  Black or African American  23.242747       23.242747
# ..   ...     ...                        ...        ...             ...
# 773   59    Male                      NHOPI  37.772967       35.884319
# 774   57  Female                      NHOPI  16.692289       15.857674
# 775   27    Male                      NHOPI  28.939233       27.492271
# 776   36  Female                      Black  20.023615       19.022434
# 777   44  Female                   Hispanic  17.605044       16.724792
#
#      Height (cm)  Weight (kg)  Abdomen Circumference  \
# 0          168.6       118.70              132.63000
# 1          157.2        83.10              112.16000
# 2          171.6        79.60               96.76000
# 3          165.4        86.20              116.00500
# 4          169.7        82.20              104.06500
# ..           ...          ...                    ...
# 773        177.6       111.65              111.08182
# 774        164.7        52.15               84.63026
# 775        170.1        73.80               92.18422
# 776        165.2        55.35               81.00822
# 777        165.2        53.90               88.13292
#
#      Ankle Circumference Left  Arm Length Left  Arm Volume Left  \
# 0                   24.650000         55.55000      5457.650000
# 1                   25.350000         58.27500      5443.915000
# 2                   22.950000         59.17500      4933.300000
# 3                   23.345000         58.97500      4591.755000
# 4                   25.555000         60.83500      4998.545000
# ..                        ...              ...              ...
# 773                 27.066240         59.43092      4841.240953
# 774                 18.610072         55.12816      2923.458640
# 775                 24.268430         60.71362      3941.097550
# 776                 21.394166         53.89626      3125.511583
# 777                 20.645882         54.39410      2476.582423
#
#      Bicep Circumference Left  Calf Circumference Left      Chest  \
# 0                    41.78000                 46.04000  133.70000
# 1                    40.13000                 42.39500  106.51000
# 2                    34.72500                 34.90500  101.67500
# 3                    38.35000                 39.53500  106.84000
# 4                    37.26000                 36.39000   97.61500
# ..                        ...                      ...        ...
# 773                  41.79824                 43.73626  118.82120
# 774                  27.75966                 31.27248   81.85404
# 775                  32.81172                 34.73450   95.97898
# 776                  27.48026                 33.27908   78.03388
# 777                  24.77516                 32.86760   80.78724
#
#      Collar Circumference  Forearm Circumference Left  Head Circumference  \
# 0                41.47000                   30.740000            55.61000
# 1                36.11500                   32.390000            59.49000
# 2                42.96500                   30.475000            56.34500
# 3                34.64500                   29.815000            57.91000
# 4                36.70500                   30.270000            57.80500
# ..                    ...                         ...                 ...
# 773              46.25848                   31.689040            55.53964
# 774              30.72384                   22.424898            56.49976
# 775              37.36848                   28.112720            56.89600
# 776              31.82620                   24.668226            59.67730
# 777              31.13278                   21.735796            53.62448
#
#      Hip Circumference  Horizontal Waist  Inseam Left  Leg Volume Left  \
# 0            133.67000         133.69000     78.88000     15265.050000
# 1            116.09500         106.72000     74.29000     12323.305000
# 2             99.05000          97.94500     77.53500      8351.140000
# 3            116.77500         110.00000     79.22000     12148.475000
# ..                ...               ...                        ...
# 773          58.52160       5386.439770                  42.123360
# 774          55.88000       3013.915432                  27.287220
# 775          59.79668       4245.242126                  32.837120
# 776          54.29250       3221.539989                  27.238960
# 777          54.41950       2707.312791                  25.176988
#
#      Calf Circumference Right  Forearm Circumference Right  Inseam Right  \
# 0                    46.04000                    32.270000      79.00000
# 1                    42.20500                    32.300000      74.12500
# 2                    33.84500                    31.110000      78.02000
# 3                    38.49000                    28.490000      79.21500
# 4                    36.20000                    30.555000      65.04000
# ..                        ...                          ...           ...
# 773                  43.97502                    34.688780      75.13320
# 774                  32.66694                    23.005034      73.46442
# 775                  34.75228                    27.932380      74.95286
# 776                  33.62452                    24.583390      76.12126
# 777                  33.81248                    22.889718      76.00442
#
#      Leg Volume Right  MidThigh Circumference Right  Outside Leg Length Right  \
# 0                 NaN                      67.78000                 106.53000
# 1        11998.945000                      57.36000                  96.81500
# 2         8037.555000                      44.12500                 109.14000
# 3        11270.055000                      53.74000                 106.18500
# 4         7031.200000                      41.91000                 103.61000
# ..                ...                           ...                       ...
# 773      11396.080953                      52.01412                 104.67594
# 774       6390.805129                      40.50792                 101.43236
# 775       8050.818359                      42.66184                  99.02444
# 776       7747.984751                      43.60926                 102.96906
# 777       7218.517550                      41.84396                 100.09886
#
#      1  Surface Area Arm Right  1  Surface Area Leg Right  \
# 0                   1640.82000                 5163.59000
# 1                   1864.38000                 4592.27000
# 2                   1776.26500                 4060.66500
# 3                   1894.21500                 4396.78500
# 4                   1800.63000                 3822.63000
# ..                         ...                        ...
# 773                 2036.83188                 4871.45356
# 774                 1298.52952                 3627.63700
# 775                 1691.84344                 4139.28060
# 776                 1307.49780                 3986.81984
# 777                 1269.36648                 3847.77924
#
#      1  Thigh Circumference Right  Upper Arm Circumference Right
# 0                        79.80000                       46.23000
# 1                        70.07500                       40.72000
# 2                        56.05000                       38.98500
# 3                        68.25500                       39.74500
# 4                        53.55000                       38.84000
# ..                            ...                            ...
# 773                      63.47206                       45.10786
# 774                      50.58410                       30.57906
# 775                      54.73700                       35.04946
# 776                      52.85994                       28.01366
# 777                      50.72888                       28.74772
#
# [778 rows x 49 columns]

# %%
in_data['Gender'] = in_data['Gender'].map({'Male' : 1, 'Female' : 0})

in_data['Race'] = LabelEncoder().fit_transform(in_data['Race'])

# %%
out_data = out_data.drop(columns = [0, 'Subject ID'])

# %%
out_data
# Out:
#      Age  Height (cm)  Weight  Gender                       Race  DXA Weight  \
# 0     41        168.6  118.70  Female  Black or African American  118.700000
# 1     33        157.2   83.10  Female                      Asian   83.100000
# 2     65        171.6   79.60    Male  Black or African American   79.600000
# 3     45        165.4   86.20  Female  Black or African American   86.200000
# 4     22        169.7   82.20  Female  Black or African American   82.200000
# ..   ...          ...     ...     ...                        ...         ...
# 773   59        177.6  111.65    Male                      NHOPI  112.321534
# 774   57        164.7   52.15  Female                      NHOPI   52.228525
# 775   27        170.1   73.80    Male                      NHOPI   74.023970
# 776   36        165.2   55.35  Female                      Black   54.669702
# 777   44        165.2   53.90  Female                   Hispanic   53.940095
#
#      Total Fat  Total Lean  Total BMC        ALM  ALM (adjusted)  \
# 773           2236.499347            6019.050052             255.895215
# 774            635.763627            2480.677825             138.085654
# 775            623.120372            4477.187064             228.808317
# 776            474.095063            2650.699921             134.842151
# 777            600.593774            2257.088897             139.077111
#
#      Fat Mass - Right Leg  Lean Mass - Right Leg  Bone Mass - Right Leg
# 0             8715.957063           12082.964301             549.369293
# 1             7043.388160            7787.781188             376.706868
# 2             2698.328720            8925.011336             507.251555
# 3             7697.844306            7674.179944             424.017168
# 4             6185.298650            8877.987038             566.389704
# ..                    ...                    ...                    ...
# 773           3962.803733           12904.083761             556.744240
# 774           2065.175741            6149.351244             349.959116
# 775           2130.531088           10054.167552             462.093810
# 776           2002.599650            7463.346511             340.149032
# 777           2717.716258            6818.824061             347.173865
#
# [778 rows x 30 columns]

# %%
out_data['Gender'] = out_data['Gender'].map({'Male' : 1, 'Female' : 0})

out_data['Race'] = LabelEncoder().fit_transform(out_data['Race'])

# %%
in_data.isna().sum(), out_data.isna().sum()
# Out:
# (Age                                0
#  Gender                             1
#  Race                               0
#  ALM                                0
#  ALM (adjusted)                     0
#  Height (cm)                        0
#  Weight (kg)                        0
#  Abdomen Circumference             10
#  Ankle Circumference Left          10
#  Arm Length Left                   19
#  Arm Volume Left                   18
#  Bicep Circumference Left           9
#  Calf Circumference Left           10
#  Chest                             20
#  Collar Circumference              20
#  Forearm Circumference Left        15
#  Head Circumference                15
#  Hip Circumference                 16
#  Horizontal Waist                   9
#  Inseam Left                        3
#  Leg Volume Left                    5
#  MidThigh Circumference Left        7
#  Narrow Waist                      12
#  Outside Leg Length Left            9
#  Seat Circumference                10
#  Surface Area Arm Left             12
#  Surface Area Leg Left              5
#  Surface Area Torso                12
#  Surface Area Total                 7
#  Thigh Circumference Left          12
#  Torso Volume                      14
#  Upper Arm Circumference Left     112
#  Volume                             8
#  Waist Circumference               10
#  Subject Height                     7
#  Ankle Circumference Right         12
#  Arm Length Right                  25
#  Arm Volume Right                  20
#  Bicep Circumference Right         17
#  Calf Circumference Right          12
#  Forearm Circumference Right       13
#  Inseam Right                       3
#  Leg Volume Right                  15
#  MidThigh Circumference Right      11
#  Outside Leg Length Right           7
#  1  Surface Area Arm Right         22
#  1  Surface Area Leg Right          6
#  1  Thigh Circumference Right      13
#  Upper Arm Circumference Right    118
#  dtype: int64,
#  Age                       0
#  Height (cm)               3
#  Weight                    1
#  Gender                    1
#  Race                      0
#  DXA Weight                0
#  Total Fat                 7
#  Total Lean                0
#  Total BMC                 3
#  ALM                       0
#  ALM (adjusted)            0
#  Fat Mass - Total          7
#  Lean Mass - Total         1
#  Bone Mass - Total         4
#  ALM.1                     0
#  Fat Mass - Trunk          8
#  Lean Mass - Trunk         2
#  Bone Mass - Trunk         9
#  Fat Mass - Left Arm      15
#  Lean Mass - Left Arm      0
#  Bone Mass - Left Arm      9
#  Fat Mass - Left Leg      12
#  Lean Mass - Left Leg      0
#  Bone Mass - Left Leg      4
#  Fat Mass - Right Arm     13
#  Lean Mass - Right Arm     0
#  Bone Mass - Right Arm     8
#  Fat Mass - Right Leg     16
#  Lean Mass - Right Leg     0
#  Bone Mass - Right Leg     7
#  dtype: int64)

# %%
# in_data.dropna(inplace=True)
# out_data.dropna(inplace=True)

in_data = in_data.fillna(in_data.mean())
out_data = out_data.fillna(out_data.mean())

# %%
in_data.isna().sum(), out_data.isna().sum()
# Out:
# (Age                              0
#  Gender                           0
#  Race                             0
#  ALM                              0
#  ALM (adjusted)                   0
#  Height (cm)                      0
#  Weight (kg)                      0
#  Abdomen Circumference            0
#  Ankle Circumference Left         0
#  Arm Length Left                  0
#  Arm Volume Left                  0
#  Bicep Circumference Left         0
#  Calf Circumference Left          0
#  Chest                            0
#  Collar Circumference             0
#  Forearm Circumference Left       0
#  Head Circumference               0
#  Hip Circumference                0
#  Horizontal Waist                 0
#  Inseam Left                      0
#  Leg Volume Left                  0
#  MidThigh Circumference Left      0
#  Narrow Waist                     0
#  Outside Leg Length Left          0
#  Seat Circumference               0
#  Surface Area Arm Left            0
#  Surface Area Leg Left            0
#  Surface Area Torso               0
#  Surface Area Total               0
#  Thigh Circumference Left         0
#  Torso Volume                     0
#  Upper Arm Circumference Left     0
#  Volume                           0
#  Waist Circumference              0
#  Subject Height                   0
#  Ankle Circumference Right        0
#  Arm Length Right                 0
#  Arm Volume Right                 0
#  Bicep Circumference Right        0
#  Calf Circumference Right         0
#  Forearm Circumference Right      0
#  Inseam Right                     0
#  Leg Volume Right                 0
#  MidThigh Circumference Right     0
#  Outside Leg Length Right         0
#  1  Surface Area Arm Right        0
#  1  Surface Area Leg Right        0
#  1  Thigh Circumference Right     0
#  Upper Arm Circumference Right    0
#  dtype: int64,
#  Age                      0
#  Height (cm)              0
#  Weight                   0
#  Gender                   0
#  Race                     0
#  DXA Weight               0
#  Total Fat                0
#  Total Lean               0
#  Total BMC                0
#  ALM                      0
#  ALM (adjusted)           0
#  Fat Mass - Total         0
#  Lean Mass - Total        0
#  Bone Mass - Total        0
#  ALM.1                    0
#  Fat Mass - Trunk         0
#  Lean Mass - Trunk        0
#  Bone Mass - Trunk        0
#  Fat Mass - Left Arm      0
#  Lean Mass - Left Arm     0
#  Bone Mass - Left Arm     0
#  Fat Mass - Left Leg      0
#  Lean Mass - Left Leg     0
#  Bone Mass - Left Leg     0
#  Fat Mass - Right Arm     0
#  Lean Mass - Right Arm    0
#  Bone Mass - Right Arm    0
#  Fat Mass - Right Leg     0
#  Lean Mass - Right Leg    0
#  Bone Mass - Right Leg    0
#  dtype: int64)

# %%
len(in_data), len(out_data)
# Out:
# (778, 778)

# %% [markdown]
# # Train / Test Split

# %%
train_percent, seed = 0.8, 1

in_training_data = in_data.sample(frac=train_percent, random_state=seed)
out_training_data = out_data.sample(frac=train_percent, random_state=seed)

in_testing_data = in_data.drop(in_training_data.index)
out_testing_data = out_data.drop(out_training_data.index)

# %% [markdown]
# # Linear Regression

# %%
model = LinearRegression().fit(in_training_data, out_training_data)
A, b = model.coef_, model.intercept_
y_pred = model.predict(in_testing_data)

print(f"R² Score = {model.score(in_training_data, out_training_data)}")
print(f'MSE = {mean_squared_error(out_testing_data, y_pred)}')
print(f'RMSE = {mean_squared_error(out_testing_data, y_pred, squared=False)}')
# Out:
# R² Score = 0.946313764086316
# MSE = 700306.2670363616
# RMSE = 393.73983000908845
